# %%
# !pip install twilio==5.7.0
# Out:
# ...
#   Running setup.py bdist_wheel for twilio: started
#   Running setup.py bdist_wheel for twilio: finished with status 'done'
#   Stored in directory: C:\Users\Usuario\AppData\Local\pip\Cache\wheels\b5\99\1d\3626f085ed601453fe4e969340b13d1de5d62c668771c543f2
#   Running setup.py bdist_wheel for httplib2: started
#   Running setup.py bdist_wheel for httplib2: finished with status 'done'
#   Stored in directory: C:\Users\Usuario\AppData\Local\pip\Cache\wheels\98\82\0d\cfb126a5e40d487157e43fdb3332937713dde36b4d0e1e754d
# Successfully built twilio httplib2
# ...

# %%
from twilio.rest import TwilioRestClient

# %%
TWILIO_PHONE_NUMBER = "+12063504079"

# %%
DIAL_NUMBERS = ["+59163949159"]

# %%
TWIML_INSTRUCTIONS_URL = \
"https://vidaenred.org/llamada-Sist_Com.xml"

client = TwilioRestClient ("AC1f8b4416075c83145dfd8d48f0d1d856","57cc3f2d07cc2e7d3d7bff7a1e459127")

# %%
def dial_numbers(numbers_list):
    for number in numbers_list:
        print("Dialing"+number)
        
        client.calls.create(to=number, from_=TWILIO_PHONE_NUMBER,url=TWIML_INSTRUCTIONS_URL, method= "GET")

# %%
if __name__ == "__main__":
    
    dial_numbers(DIAL_NUMBERS)
# Out:
# Dialing+59163949159

# %% [markdown]
# # Preguntas
#     1. ¿Explica para que sirve el archivo https://vidaenred.org/llamada-Sist_Com.xml”?
#         Sirve para que mediante un automata responda al texto predefinido al momento de contestar la llamada
#     2. ¿Para qué sirve la librería Twilio?
#         Se usa para definir el SID (AC1f8b4416075c83145dfd8d48f0d1d856) y el token (57cc3f2d07cc2e7d3d7bff7a1e459127) los cuales son necesarios para realizar la comunicacion
#     3. Explica esta función:def dial_numbers(numbers_list):
#         “””Dials one or more phone numbers from a Twilio phone number.””” for number in numbers_list:
#
#         print(“Dialing “ + number)
#
#         client.calls.create(to=number, from_=TWILIO_PHONE_NUMBER,
#
#         url=TWIML_INSTRUCTIONS_URL, method=“GET”)
#
#         Sirve para marcar los numeros que desees, estos numeros se los almacena en el arrays

# %% [markdown]
# ![image.png](attachment:image.png)
